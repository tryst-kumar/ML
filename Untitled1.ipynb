# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as stats

# %%
ard = [80, 85, 90, 95, 100, 105, 110, 120, 125]
print(ard)
# Out:
# [80, 85, 90, 95, 100, 105, 110, 120, 125]

# %%
d = {'col1': [1, 2, 3, 4, 7], 'col2': [4, 5, 6, 9, 5],
     'col3': [7, 8, 12, 1, 11]}

df = pd.DataFrame(data = d)
print(df)
# Out:
#    col1  col2  col3
# 0     1     4     7
# 1     2     5     8
# 2     3     6    12
# 3     4     9     1
# 4     7     5    11

# %%
count_column = df.shape[1]
print(count_column)
# Out:
# 3

# %%
count_row = df.shape[0]
print(count_row)
# Out:
# 5

# %%
pulse_rates_max = max(80, 85, 90, 95, 100, 105, 110, 115, 120, 125)
print(pulse_rates_max)
# Out:
# 125

# %%
print(min([80, 85, 90, 95, 100, 105, 110, 115, 120, 125]))
# Out:
# 80

# %%
x = np.random.uniform(0.0, 5.0, 250)
print(x)
# Out:
# [3.85742254 2.3990794  2.50992493 3.72766927 3.77430988 0.81109848
#  4.70531182 1.13613703 3.59002298 4.37988135 2.72002756 4.3654953
#  0.44960724 3.40365123 1.29082308 4.90053179 4.2055407  1.86225675
#  0.75198938 4.13895128 4.44544554 0.5244537  3.15649456 3.62525249
#  4.27471562 3.2236801  1.38970838 3.92840623 1.95883151 0.08631984
#  4.61075789 3.7461259  1.78903861 2.60234625 1.56831808 1.92710654
#  4.82149765 0.57839289 2.50295933 3.52140959 4.90735721 2.25456537
#  1.22503376 4.18972272 0.62511807 3.3667789  3.95188771 4.36250118
#  1.54337738 3.5446471  3.70265223 4.41378175 3.64786863 4.29896889
#  4.02593527 4.30699406 1.2828313  2.94878112 3.22859539 1.78822517
#  1.55169813 0.57734274 4.71760152 3.33138817 1.05646797 4.05449578
#  4.18410261 3.46289642 3.83665875 0.90302259 3.72751513 2.18845131
#  2.4716931  0.20646956 3.36625556 4.89506946 1.0315159  4.33206945
#  1.83590192 3.91715392 3.91220597 2.98447452 3.93648025 2.71101938
# ...

# %%
plt.hist(x, 5)
plt.show()

# %%
y = np.random.uniform(0.0, 5.0, 100000)

plt.hist(y, 100)
plt.show()

# %%
z = np.random.normal(5.0, 1.0, 100000)

plt.hist(z, 100)
plt.show()

# %%
x = [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
y = [99, 86, 87, 88, 111, 86, 103, 87, 94, 78, 77, 85, 86]

plt.scatter(x, y)
plt.show()

# %%
from scipy import stats
slope, intercept, r, p, std_err = stats.linregress(x, y)

def myfunc(x):
    return slope * x + intercept

mymodel = list(map(myfunc, x))

plt.scatter(x, y)
plt.plot(x, mymodel)

plt.show()

# %%
x = np.random.normal(5.0, 1.0, 1000)
y = np.random.normal(10.0, 2.0, 1000)

plt.scatter(x, y)
plt.show()
